# %% [markdown]
# # The extensive evaluation of all variations of the estimators

# %%
import os

import numpy as np
import pandas as pd

from conditioning_bias import (OperatorDecisionTreeClassifier,
                                    OperatorDecisionTreeRegressor,
                                    OperatorRandomForestClassifier,
                                    OperatorRandomForestRegressor)

from datasets import binclas_datasets, regr_datasets
from evaluation import evaluate_classification, evaluate_regression
from config import n_repeats, n_splits, dataset_map, data_dir, random_seed

# %%
labels = ['dtc', 'dtr', 'rfc', 'rfr']
params = {}
postfix = ''

# %%
for label in labels:
    params[label] = {}
    best_params = pd.read_csv(os.path.join(data_dir, f'params_{label}.csv'))
    for idx, row in best_params.iterrows():
        params[label][row['name']] = eval(row['params'])

# %%
configurations = {
    'dtc': {
        'datasets': binclas_datasets,
        'estimator': OperatorDecisionTreeClassifier,
        'function': evaluate_classification,
        'label': 'dtc',
        'modes': OperatorDecisionTreeClassifier().get_modes()
        },
    'rfc': {
        'datasets': binclas_datasets,
        'estimator': OperatorRandomForestClassifier,
        'function': evaluate_classification,
        'label': 'rfc',
        'modes': OperatorRandomForestClassifier().get_modes()
        },
    'dtr': {
        'datasets': regr_datasets,
        'estimator': OperatorDecisionTreeRegressor,
        'function': evaluate_regression,
        'label': 'dtr',
        'modes': OperatorDecisionTreeRegressor().get_modes()
        },
    'rfr': {
        'datasets': regr_datasets,
        'estimator': OperatorRandomForestRegressor,
        'function': evaluate_regression,
        'label': 'rfr',
        'modes': OperatorRandomForestRegressor().get_modes()
        },
}

# %%
for key, conf in configurations.items():
    print(key, conf)

    results = conf['function'](
        datasets=conf['datasets'],
        estimator=conf['estimator'],
        params=params[key],
        modes=conf['modes'],
        validator_params={'n_splits': n_splits, 'n_repeats': n_repeats, 'random_state': 5},
        random_seed=random_seed
    )

    results['name'] = results['name'].apply(lambda x: dataset_map.get(x, x))

    results.to_csv(os.path.join(data_dir, f'evaluation_{key}{postfix}.csv'))
# Out:
# dtc {'datasets':                             name citation_key  n_col    n  n_minority  n_grid  \
# 0                   appendicitis         keel      7  106          21       7
# 1                       haberman         keel      3  306          81       3
# 2                   new_thyroid1         keel      5  215          35       5
# 3                         glass0         keel      9  214          70       9
# 4               shuttle-6_vs_2-3         keel      9  230          10       9
# 5                           bupa         keel      6  345         145       6
# 6               cleveland-0_vs_4         keel     13  177          13      10
# 7                         ecoli1         keel      7  336          77       5
# 8                   poker-9_vs_7         keel     10  244           8      10
# 9                         monk-2         keel      6  432         204       4
# 10                     hepatitis         krnn     19  155          32       6
# 11          yeast-0-3-5-9_vs_7-8         keel      8  506          50       6
# 12                  mammographic         keel      5  830         403       5
# 13                       saheart         keel      9  462         160       8
# 14          page-blocks-1-3_vs_4         keel     10  472          28      10
# 15  lymphography-normal-fibrosis         keel     32  148           6       3
# 16                          pima         keel      8  768         268       8
# 17                     wisconsin         keel      9  683         239       9
# 18                   abalone9_18         keel      9  731          42       7
# 19        winequality-red-3_vs_5         keel     11  691          10      11
#
#                                  data_loader_function
# 0      <function load_appendicitis at 0x7f8fe4b06b00>
# 1          <function load_haberman at 0x7f8fe4b06680>
# 2      <function load_new_thyroid1 at 0x7f8fe4b067a0>
# 3            <function load_glass0 at 0x7f8fe4b041f0>
# 4   <function load_shuttle_6_vs_2_3 at 0x7f8fe4b05...
# 5              <function load_bupa at 0x7f8fe4b06e60>
# 6   <function load_cleveland_0_vs_4 at 0x7f8fe4b06...
# 7            <function load_ecoli1 at 0x7f8fe4adba30>
# 8      <function load_poker_9_vs_7 at 0x7f8fe4b05a20>
# 9            <function load_monk_2 at 0x7f8fe4b06cb0>
# 10        <function load_hepatitis at 0x7f8fe4b07250>
# 11  <function load_yeast_0_3_5_9_vs_7_8 at 0x7f8fe...
# 12     <function load_mammographic at 0x7f8fe4b06a70>
# 13          <function load_saheart at 0x7f8fe4b06b90>
# 14  <function load_page_blocks_1_3_vs_4 at 0x7f8fe...
# 15  <function load_lymphography_normal_fibrosis at...
# 16             <function load_pima at 0x7f8fe4b068c0>
# 17        <function load_wisconsin at 0x7f8fe4b069e0>
# 18      <function load_abalone9_18 at 0x7f8fe4adb0a0>
# 19  <function load_winequality_red_3_vs_5 at 0x7f8...  , 'estimator': <class 'conditioning_bias._classifiers.OperatorDecisionTreeClassifier'>, 'function': <function evaluate_classification at 0x7f901c37c3a0>, 'label': 'dtc', 'modes': ['<', '<=', 'avg_full', 'avg_rand']}
# 2023-12-11 21:01:36.289103 appendicitis
# 2023-12-11 21:01:59.878932 haberman
# 2023-12-11 21:02:30.229312 new_thyroid1
# 2023-12-11 21:02:56.303004 glass0
# 2023-12-11 21:03:20.125075 shuttle-6_vs_2-3
# 2023-12-11 21:03:40.161722 bupa
# 2023-12-11 21:04:05.695513 cleveland-0_vs_4
# 2023-12-11 21:04:29.506927 ecoli1
# 2023-12-11 21:04:53.040715 poker-9_vs_7
# 2023-12-11 21:05:13.121637 monk-2
# 2023-12-11 21:05:32.559041 hepatitis
# 2023-12-11 21:05:52.227245 yeast-0-3-5-9_vs_7-8
# 2023-12-11 21:06:15.498808 mammographic
# 2023-12-11 21:06:36.667445 saheart
# 2023-12-11 21:06:58.083683 page-blocks-1-3_vs_4
# 2023-12-11 21:07:17.730981 lymphography-normal-fibrosis
# 2023-12-11 21:07:36.212653 pima
# 2023-12-11 21:08:00.106214 wisconsin
# 2023-12-11 21:08:21.283253 abalone9_18
# 2023-12-11 21:08:42.215631 winequality-red-3_vs_5
# rfc {'datasets':                             name citation_key  n_col    n  n_minority  n_grid  \
# 0                   appendicitis         keel      7  106          21       7
# 1                       haberman         keel      3  306          81       3
# 2                   new_thyroid1         keel      5  215          35       5
# 3                         glass0         keel      9  214          70       9
# 4               shuttle-6_vs_2-3         keel      9  230          10       9
# 5                           bupa         keel      6  345         145       6
# 6               cleveland-0_vs_4         keel     13  177          13      10
# 7                         ecoli1         keel      7  336          77       5
# 8                   poker-9_vs_7         keel     10  244           8      10
# 9                         monk-2         keel      6  432         204       4
# 10                     hepatitis         krnn     19  155          32       6
# 11          yeast-0-3-5-9_vs_7-8         keel      8  506          50       6
# 12                  mammographic         keel      5  830         403       5
# 13                       saheart         keel      9  462         160       8
# 14          page-blocks-1-3_vs_4         keel     10  472          28      10
# 15  lymphography-normal-fibrosis         keel     32  148           6       3
# 16                          pima         keel      8  768         268       8
# 17                     wisconsin         keel      9  683         239       9
# 18                   abalone9_18         keel      9  731          42       7
# 19        winequality-red-3_vs_5         keel     11  691          10      11
#
#                                  data_loader_function
# 0      <function load_appendicitis at 0x7f8fe4b06b00>
# 1          <function load_haberman at 0x7f8fe4b06680>
# 2      <function load_new_thyroid1 at 0x7f8fe4b067a0>
# 3            <function load_glass0 at 0x7f8fe4b041f0>
# 4   <function load_shuttle_6_vs_2_3 at 0x7f8fe4b05...
# 5              <function load_bupa at 0x7f8fe4b06e60>
# 6   <function load_cleveland_0_vs_4 at 0x7f8fe4b06...
# 7            <function load_ecoli1 at 0x7f8fe4adba30>
# 8      <function load_poker_9_vs_7 at 0x7f8fe4b05a20>
# 9            <function load_monk_2 at 0x7f8fe4b06cb0>
# 10        <function load_hepatitis at 0x7f8fe4b07250>
# 11  <function load_yeast_0_3_5_9_vs_7_8 at 0x7f8fe...
# 12     <function load_mammographic at 0x7f8fe4b06a70>
# 13          <function load_saheart at 0x7f8fe4b06b90>
# 14  <function load_page_blocks_1_3_vs_4 at 0x7f8fe...
# 15  <function load_lymphography_normal_fibrosis at...
# 16             <function load_pima at 0x7f8fe4b068c0>
# 17        <function load_wisconsin at 0x7f8fe4b069e0>
# 18      <function load_abalone9_18 at 0x7f8fe4adb0a0>
# 19  <function load_winequality_red_3_vs_5 at 0x7f8...  , 'estimator': <class 'conditioning_bias._classifiers.OperatorRandomForestClassifier'>, 'function': <function evaluate_classification at 0x7f901c37c3a0>, 'label': 'rfc', 'modes': ['<', '<=', 'avg_all', 'avg_half']}
# 2023-12-11 21:09:04.689226 appendicitis
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/gykovacs/workspaces/decision_tree_conditioning_bias/study/005-evaluation.ipynb Cell 6 line 4
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/gykovacs/workspaces/decision_tree_conditioning_bias/study/005-evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> for key, conf in configurations.items():
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/gykovacs/workspaces/decision_tree_conditioning_bias/study/005-evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     print(key, conf)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/gykovacs/workspaces/decision_tree_conditioning_bias/study/005-evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     results = conf['function'](
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/gykovacs/workspaces/decision_tree_conditioning_bias/study/005-evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>         datasets=conf['datasets'],
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/gykovacs/workspaces/decision_tree_conditioning_bias/study/005-evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>         estimator=conf['estimator'],
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/gykovacs/workspaces/decision_tree_conditioning_bias/study/005-evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>         params=params[key],
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/gykovacs/workspaces/decision_tree_conditioning_bias/study/005-evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>         modes=conf['modes'],
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/gykovacs/workspaces/decision_tree_conditioning_bias/study/005-evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>         validator_params={'n_splits': n_splits, 'n_repeats': n_repeats, 'random_state': 5},
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/gykovacs/workspaces/decision_tree_conditioning_bias/study/005-evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>         random_seed=random_seed
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/gykovacs/workspaces/decision_tree_conditioning_bias/study/005-evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     )
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/gykovacs/workspaces/decision_tree_conditioning_bias/study/005-evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     results['name'] = results['name'].apply(lambda x: dataset_map.get(x, x))
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/gykovacs/workspaces/decision_tree_conditioning_bias/study/005-evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>     results.to_csv(os.path.join(data_dir, f'evaluation_{key}{postfix}.csv'))
#
# File ~/workspaces/decision_tree_conditioning_bias/study/evaluation.py:82, in evaluate_classification(datasets, estimator, modes, params, validator_params, random_seed)
#      80             for idx, mode in enumerate(modes):
#      81                 classifier.set_mode(mode)
# ---> 82                 y_pred = classifier.predict_proba(X_test)[:, 1]
#      84                 results.append({'name': dataset['name'],
#      85                                 'fold': fdx,
#      86                                 'auc': roc_auc_score(y_test, y_pred),
#      87                                 'mode': mode,
#      88                                 'params': par,
#      89                                 'estimator': estimator.__name__})
#      91 return pd.DataFrame(results)
#
# File ~/workspaces/decision_tree_conditioning_bias/conditioning_bias/_classifiers.py:294, in OperatorRandomForestClassifier.predict_proba(self, X)
#     291     return self.predict_proba_operator(X)
#     293 # elif self.mode in ["avg_all", "avg_half"]:
# --> 294 return self.predict_proba_average(X)
#
# File ~/workspaces/decision_tree_conditioning_bias/conditioning_bias/_classifiers.py:262, in OperatorRandomForestClassifier.predict_proba_average(self, X)
#     250 """
#     251 Predict probabilities by averaging
#     252
#    (...)
#     257     np.array: the predicted probabilities
#     258 """
#     259 if self.mode == "avg_all":
#     260     return np.mean(
#     261         [
# --> 262             _evaluate_trees(X, self.forest.estimators_, "<"),
#     263             _evaluate_trees(X, self.forest.estimators_, "<="),
#     264         ],
#     265         axis=0,
#     266     )
#     268 n_estimators = len(self.forest.estimators_)
#     269 n_half = int(n_estimators / 2)
#
# File ~/workspaces/decision_tree_conditioning_bias/conditioning_bias/_classifiers.py:169, in _evaluate_trees(X, trees, operator)
#     167 values = []
#     168 for tree in trees:
# --> 169     nodes = apply(X=X, tree=tree, operator=operator)
#     170     values.append(tree.tree_.value[nodes][:, 0, :])
#     172 values = [(value.T / np.sum(value, axis=1)).T for value in values]
#
# File ~/workspaces/decision_tree_conditioning_bias/conditioning_bias/_tree_inference.py:30, in apply(X, tree, operator, random_state)
#      27 if not isinstance(random_state, np.random.RandomState):
#      28     random_state = np.random.RandomState(random_state)
# ---> 30 while not np.all(leaf_node_flag[node_ids]):
#      31     # the indices of vectors not at leaf nodes yet
#      32     active_indices = np.where(~leaf_node_flag[node_ids])[0]
#      34     # the actual nodes where these vectors are
#
# File ~/anaconda3/envs/splitting-bias/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2421, in all(a, axis, out, keepdims, where)
#    2416 def _all_dispatcher(a, axis=None, out=None, keepdims=None, *,
#    2417                     where=None):
#    2418     return (a, where, out)
# -> 2421 @array_function_dispatch(_all_dispatcher)
#    2422 def all(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#    2423     """
#    2424     Test whether all array elements along a given axis evaluate to True.
#    2425
#    (...)
#    2502
#    2503     """
#    2504     return _wrapreduction(a, np.logical_and, 'all', axis, None, out,
#    2505                           keepdims=keepdims, where=where)
#
# KeyboardInterrupt:
