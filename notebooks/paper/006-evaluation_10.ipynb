# %%
import copy

import numpy as np
import pandas as pd

from flipping_random_forest import (OperatorDecisionTreeClassifier,
                                    OperatorDecisionTreeRegressor,
                                    OperatorRandomForestClassifier,
                                    OperatorRandomForestRegressor)

from datasets import binclas_datasets, regr_datasets
from evaluation import evaluate_classification, evaluate_regression
from config import n_repeats_10, n_splits_10, dataset_map
# Out:
# 2023-12-06 17:27:30 INFO     querying the filtered classification datasets
# 2023-12-06 17:27:30 INFO     ranking the datasets
# 2023-12-06 17:27:30 INFO     binary classification datasets prepared
# 2023-12-06 17:27:30 INFO     querying the filtered regression datasets
# 2023-12-06 17:27:30 INFO     ranking the datasets
# 2023-12-06 17:27:30 INFO     regression datasets prepared

# %%
labels = ['dtc', 'dtr', 'rfc', 'rfr']
params = {}
postfix = '_10'

# %%
for label in labels:
    params[label] = {}
    best_params = pd.read_csv(f'params_{label}.csv')
    for idx, row in best_params.iterrows():
        params[label][row['name']] = eval(row['params'])

# %%
configurations = {
    'dtc': {
        'datasets': binclas_datasets,
        'estimator': OperatorDecisionTreeClassifier,
        'function': evaluate_classification,
        'label': 'dtc',
        'modes': OperatorDecisionTreeClassifier().get_modes()
        },
    'rfc': {
        'datasets': binclas_datasets,
        'estimator': OperatorRandomForestClassifier,
        'function': evaluate_classification,
        'label': 'rfc',
        'modes': OperatorRandomForestClassifier().get_modes()
        },
    'dtr': {
        'datasets': regr_datasets,
        'estimator': OperatorDecisionTreeRegressor,
        'function': evaluate_regression,
        'label': 'dtr',
        'modes': OperatorDecisionTreeRegressor().get_modes()
        },
    'rfr': {
        'datasets': regr_datasets,
        'estimator': OperatorRandomForestRegressor,
        'function': evaluate_regression,
        'label': 'rfr',
        'modes': OperatorRandomForestRegressor().get_modes()
        },
}

# %%
for key, conf in configurations.items():
    print(key, conf)

    results = conf['function'](
        datasets=conf['datasets'],
        estimator=conf['estimator'],
        params=params[key],
        modes=conf['modes'],
        validator_params={'n_splits': n_splits_10, 'n_repeats': n_repeats_10, 'random_state': 5},
        random_state=5
    )


    results['name'] = results['name'].apply(lambda x: dataset_map.get(x, x))

    results.to_csv(f'evaluation_{key}{postfix}.csv')
# Out:
# dtc {'datasets':                             name citation_key  n_col    n  n_minority  n_grid  \
# 0                   appendicitis         keel      7  106          21       7
# 1                       haberman         keel      3  306          81       3
# 2                   new_thyroid1         keel      5  215          35       5
# 3                         glass0         keel      9  214          70       9
# 4               shuttle-6_vs_2-3         keel      9  230          10       9
# 5                           bupa         keel      6  345         145       6
# 6               cleveland-0_vs_4         keel     13  177          13      10
# 7                         ecoli1         keel      7  336          77       5
# 8                   poker-9_vs_7         keel     10  244           8      10
# 9                         monk-2         keel      6  432         204       4
# 10                     hepatitis         krnn     19  155          32       6
# 11          yeast-0-3-5-9_vs_7-8         keel      8  506          50       6
# 12                  mammographic         keel      5  830         403       5
# 13                       saheart         keel      9  462         160       8
# 14          page-blocks-1-3_vs_4         keel     10  472          28      10
# 15  lymphography-normal-fibrosis         keel     32  148           6       3
# 16                          pima         keel      8  768         268       8
# 17                     wisconsin         keel      9  683         239       9
# 18                   abalone9_18         keel      9  731          42       7
# 19        winequality-red-3_vs_5         keel     11  691          10      11
#
#                                  data_loader_function
# 0      <function load_appendicitis at 0x7f7c78df6e60>
# 1          <function load_haberman at 0x7f7c78df69e0>
# 2      <function load_new_thyroid1 at 0x7f7c78df6b00>
# 3            <function load_glass0 at 0x7f7c78df4550>
# 4   <function load_shuttle_6_vs_2_3 at 0x7f7c78df5...
# 5              <function load_bupa at 0x7f7c78df71c0>
# 6   <function load_cleveland_0_vs_4 at 0x7f7c78df6...
# 7            <function load_ecoli1 at 0x7f7c78dcfd90>
# 8      <function load_poker_9_vs_7 at 0x7f7c78df5d80>
# 9            <function load_monk_2 at 0x7f7c78df7010>
# 10        <function load_hepatitis at 0x7f7c78df75b0>
# 11  <function load_yeast_0_3_5_9_vs_7_8 at 0x7f7c7...
# 12     <function load_mammographic at 0x7f7c78df6dd0>
# 13          <function load_saheart at 0x7f7c78df6ef0>
# 14  <function load_page_blocks_1_3_vs_4 at 0x7f7c7...
# 15  <function load_lymphography_normal_fibrosis at...
# 16             <function load_pima at 0x7f7c78df6c20>
# 17        <function load_wisconsin at 0x7f7c78df6d40>
# 18      <function load_abalone9_18 at 0x7f7c78dcf400>
# 19  <function load_winequality_red_3_vs_5 at 0x7f7...  , 'estimator': <class 'flipping_random_forest._classifiers.OperatorDecisionTreeClassifier'>, 'function': <function evaluate_classification at 0x7f7ca83503a0>, 'label': 'dtc', 'modes': ['<', '<=', 'avg_full', 'avg_rand', 'specific']}
# 2023-12-06 17:27:30.613177 appendicitis
# 2023-12-06 17:28:09.802741 haberman
# 2023-12-06 17:28:39.224464 new_thyroid1
# 2023-12-06 17:29:12.199054 glass0
# 2023-12-06 17:29:54.469138 shuttle-6_vs_2-3
# 2023-12-06 17:30:33.207426 bupa
# 2023-12-06 17:31:11.402978 cleveland-0_vs_4
# 2023-12-06 17:32:10.683543 ecoli1
# 2023-12-06 17:32:55.072462 poker-9_vs_7
# 2023-12-06 17:33:32.645596 monk-2
# 2023-12-06 17:34:11.694154 hepatitis
# 2023-12-06 17:35:31.727605 yeast-0-3-5-9_vs_7-8
# 2023-12-06 17:36:15.536340 mammographic
# 2023-12-06 17:36:48.618353 saheart
# 2023-12-06 17:37:33.562669 page-blocks-1-3_vs_4
# 2023-12-06 17:38:20.439605 lymphography-normal-fibrosis
# 2023-12-06 17:39:15.126833 pima
# 2023-12-06 17:40:01.165326 wisconsin
# 2023-12-06 17:40:48.011785 abalone9_18
# 2023-12-06 17:41:40.666920 winequality-red-3_vs_5
# rfc {'datasets':                             name citation_key  n_col    n  n_minority  n_grid  \
# 0                   appendicitis         keel      7  106          21       7
# 1                       haberman         keel      3  306          81       3
# 2                   new_thyroid1         keel      5  215          35       5
# 3                         glass0         keel      9  214          70       9
# 4               shuttle-6_vs_2-3         keel      9  230          10       9
# 5                           bupa         keel      6  345         145       6
# 6               cleveland-0_vs_4         keel     13  177          13      10
# 7                         ecoli1         keel      7  336          77       5
# 8                   poker-9_vs_7         keel     10  244           8      10
# 9                         monk-2         keel      6  432         204       4
# 10                     hepatitis         krnn     19  155          32       6
# 11          yeast-0-3-5-9_vs_7-8         keel      8  506          50       6
# 12                  mammographic         keel      5  830         403       5
# 13                       saheart         keel      9  462         160       8
# 14          page-blocks-1-3_vs_4         keel     10  472          28      10
# 15  lymphography-normal-fibrosis         keel     32  148           6       3
# 16                          pima         keel      8  768         268       8
# 17                     wisconsin         keel      9  683         239       9
# 18                   abalone9_18         keel      9  731          42       7
# 19        winequality-red-3_vs_5         keel     11  691          10      11
#
#                                  data_loader_function
# 0      <function load_appendicitis at 0x7f7c78df6e60>
# 1          <function load_haberman at 0x7f7c78df69e0>
# 2      <function load_new_thyroid1 at 0x7f7c78df6b00>
# 3            <function load_glass0 at 0x7f7c78df4550>
# 4   <function load_shuttle_6_vs_2_3 at 0x7f7c78df5...
# 5              <function load_bupa at 0x7f7c78df71c0>
# 6   <function load_cleveland_0_vs_4 at 0x7f7c78df6...
# 7            <function load_ecoli1 at 0x7f7c78dcfd90>
# 8      <function load_poker_9_vs_7 at 0x7f7c78df5d80>
# 9            <function load_monk_2 at 0x7f7c78df7010>
# 10        <function load_hepatitis at 0x7f7c78df75b0>
# 11  <function load_yeast_0_3_5_9_vs_7_8 at 0x7f7c7...
# 12     <function load_mammographic at 0x7f7c78df6dd0>
# 13          <function load_saheart at 0x7f7c78df6ef0>
# 14  <function load_page_blocks_1_3_vs_4 at 0x7f7c7...
# 15  <function load_lymphography_normal_fibrosis at...
# 16             <function load_pima at 0x7f7c78df6c20>
# 17        <function load_wisconsin at 0x7f7c78df6d40>
# 18      <function load_abalone9_18 at 0x7f7c78dcf400>
# 19  <function load_winequality_red_3_vs_5 at 0x7f7...  , 'estimator': <class 'flipping_random_forest._classifiers.OperatorRandomForestClassifier'>, 'function': <function evaluate_classification at 0x7f7ca83503a0>, 'label': 'rfc', 'modes': ['<', '<=', 'avg_all', 'avg_half', 'specific']}
# 2023-12-06 17:42:30.954531 appendicitis
# 2023-12-06 17:50:36.283054 haberman
# 2023-12-06 18:00:15.309164 new_thyroid1
# 2023-12-06 18:09:19.281787 glass0
# 2023-12-06 18:20:14.663669 shuttle-6_vs_2-3
# 2023-12-06 18:29:07.495239 bupa
# 2023-12-06 18:40:39.037226 cleveland-0_vs_4
# 2023-12-06 18:49:44.651266 ecoli1
# 2023-12-06 18:59:33.603146 poker-9_vs_7
# 2023-12-06 19:06:27.685610 monk-2
# 2023-12-06 19:15:59.202611 hepatitis
# 2023-12-06 19:24:20.178564 yeast-0-3-5-9_vs_7-8
# 2023-12-06 19:34:45.644662 mammographic
# 2023-12-06 19:43:41.749601 saheart
# 2023-12-06 19:52:49.430176 page-blocks-1-3_vs_4
# 2023-12-06 20:02:21.006236 lymphography-normal-fibrosis
# 2023-12-06 20:07:51.088978 pima
# 2023-12-06 20:18:28.123375 wisconsin
# 2023-12-06 20:28:34.515022 abalone9_18
# 2023-12-06 20:40:47.913819 winequality-red-3_vs_5
# dtr {'datasets':                            name citation_key  n_col     n  n_grid  \
# 0                      diabetes         keel      2    43       2
# 1                        o-ring          uci      6    23       4
# 2   stock_portfolio_performance          uci      6    63       6
# 3                       wsn-ale          uci      5   107       4
# 4                  daily-demand          uci     12    60       7
# 5                    slump_test         krnn      9   103       9
# 6                         servo          uci     10   167       2
# 7           yacht_hydrodynamics         krnn      6   307       6
# 8                      autoMPG6         keel      5   392       5
# 9            excitation_current          uci      4   557       4
# 10        real_estate_valuation          uci      6   414       5
# 11                      wankara         keel      9   321       9
# 12                      plastic         keel      2  1650       2
# 13                        laser         keel      4   993       4
# 14        qsar-aquatic-toxicity          uci      8   546       8
# 15                     baseball         keel     16   337      12
# 16         maternal_health_risk          uci      6  1013       6
# 17              cpu_performance         krnn     35   209       6
# 18                      airfoil         krnn      5  1503       4
# 19                 medical_cost      mlwithr      6  1338       2
#
#                                                  grid  \
# 0                                        [True, True]
# 1              [False, True, False, True, True, True]
# 2                [True, True, True, True, True, True]
# 3                     [False, True, True, True, True]
# 4   [False, False, False, False, False, True, True...
# 5   [True, True, True, True, True, True, True, Tru...
# 6   [True, True, False, False, False, False, False...
# 7                [True, True, True, True, True, True]
# 8                      [True, True, True, True, True]
# 9                            [True, True, True, True]
# 10              [False, True, True, True, True, True]
# 11  [True, True, True, True, True, True, True, Tru...
# 12                                       [True, True]
# 13                           [True, True, True, True]
# 14   [True, True, True, True, True, True, True, True]
# 15  [False, False, False, False, True, True, True,...
# 16               [True, True, True, True, True, True]
# 17  [True, True, True, True, True, True, False, Fa...
# 18                    [False, True, True, True, True]
# 19           [True, True, False, False, False, False]
#
#                                  data_loader_function
# 0          <function load_diabetes at 0x7f7c78e4cca0>
# 1            <function load_o_ring at 0x7f7c78e4d6c0>
# 2   <function load_stock_portfolio_performance at ...
# 3           <function load_wsn_ale at 0x7f7c78e4d7e0>
# 4      <function load_daily_demand at 0x7f7c78e4d750>
# 5        <function load_slump_test at 0x7f7c78e4d3f0>
# 6             <function load_servo at 0x7f7c78e4d870>
# 7   <function load_yacht_hydrodynamics at 0x7f7c78...
# 8          <function load_autoMPG6 at 0x7f7c78e4cd30>
# 9   <function load_excitation_current at 0x7f7c78e...
# 10  <function load_real_estate_valuation at 0x7f7c...
# 11          <function load_wankara at 0x7f7c78e4ce50>
# 12          <function load_plastic at 0x7f7c78e4d1b0>
# 13            <function load_laser at 0x7f7c78e4cc10>
# 14  <function load_qsar_aquatic_toxicity at 0x7f7c...
# 15         <function load_baseball at 0x7f7c78e4cf70>
# 16  <function load_maternal_health_risk at 0x7f7c7...
# 17  <function load_cpu_performance at 0x7f7c78e4d2d0>
# 18          <function load_airfoil at 0x7f7c78e4d240>
# 19     <function load_medical_cost at 0x7f7c78e4dbd0>  , 'estimator': <class 'flipping_random_forest._regressors.OperatorDecisionTreeRegressor'>, 'function': <function evaluate_regression at 0x7f7ca8350430>, 'label': 'dtr', 'modes': ['<', '<=', 'avg_full', 'avg_half', 'specific']}
# 2023-12-06 20:50:27.319881 diabetes
# 2023-12-06 20:50:41.047402 o-ring
# 2023-12-06 20:51:02.857249 stock_portfolio_performance
# 2023-12-06 20:51:26.125248 wsn-ale
# 2023-12-06 20:51:51.829990 daily-demand
# 2023-12-06 20:52:49.450192 slump_test
# 2023-12-06 20:53:21.965521 servo
# 2023-12-06 20:53:55.151337 yacht_hydrodynamics
# 2023-12-06 20:54:25.222966 autoMPG6
# 2023-12-06 20:54:48.566459 excitation_current
# 2023-12-06 20:55:13.343502 real_estate_valuation
# 2023-12-06 20:55:55.244017 wankara
# 2023-12-06 20:56:31.382191 plastic
# 2023-12-06 20:56:52.528507 laser
# 2023-12-06 20:57:20.904241 qsar-aquatic-toxicity
# 2023-12-06 20:57:54.213411 baseball
# 2023-12-06 20:58:51.412925 maternal_health_risk
# 2023-12-06 20:59:25.790047 cpu_performance
# 2023-12-06 21:00:51.020907 airfoil
# 2023-12-06 21:01:27.268454 medical_cost
# rfr {'datasets':                            name citation_key  n_col     n  n_grid  \
# 0                      diabetes         keel      2    43       2
# 1                        o-ring          uci      6    23       4
# 2   stock_portfolio_performance          uci      6    63       6
# 3                       wsn-ale          uci      5   107       4
# 4                  daily-demand          uci     12    60       7
# 5                    slump_test         krnn      9   103       9
# 6                         servo          uci     10   167       2
# 7           yacht_hydrodynamics         krnn      6   307       6
# 8                      autoMPG6         keel      5   392       5
# 9            excitation_current          uci      4   557       4
# 10        real_estate_valuation          uci      6   414       5
# 11                      wankara         keel      9   321       9
# 12                      plastic         keel      2  1650       2
# 13                        laser         keel      4   993       4
# 14        qsar-aquatic-toxicity          uci      8   546       8
# 15                     baseball         keel     16   337      12
# 16         maternal_health_risk          uci      6  1013       6
# 17              cpu_performance         krnn     35   209       6
# 18                      airfoil         krnn      5  1503       4
# 19                 medical_cost      mlwithr      6  1338       2
#
#                                                  grid  \
# 0                                        [True, True]
# 1              [False, True, False, True, True, True]
# 2                [True, True, True, True, True, True]
# 3                     [False, True, True, True, True]
# 4   [False, False, False, False, False, True, True...
# 5   [True, True, True, True, True, True, True, Tru...
# 6   [True, True, False, False, False, False, False...
# 7                [True, True, True, True, True, True]
# 8                      [True, True, True, True, True]
# 9                            [True, True, True, True]
# 10              [False, True, True, True, True, True]
# 11  [True, True, True, True, True, True, True, Tru...
# 12                                       [True, True]
# 13                           [True, True, True, True]
# 14   [True, True, True, True, True, True, True, True]
# 15  [False, False, False, False, True, True, True,...
# 16               [True, True, True, True, True, True]
# 17  [True, True, True, True, True, True, False, Fa...
# 18                    [False, True, True, True, True]
# 19           [True, True, False, False, False, False]
#
#                                  data_loader_function
# 0          <function load_diabetes at 0x7f7c78e4cca0>
# 1            <function load_o_ring at 0x7f7c78e4d6c0>
# 2   <function load_stock_portfolio_performance at ...
# 3           <function load_wsn_ale at 0x7f7c78e4d7e0>
# 4      <function load_daily_demand at 0x7f7c78e4d750>
# 5        <function load_slump_test at 0x7f7c78e4d3f0>
# 6             <function load_servo at 0x7f7c78e4d870>
# 7   <function load_yacht_hydrodynamics at 0x7f7c78...
# 8          <function load_autoMPG6 at 0x7f7c78e4cd30>
# 9   <function load_excitation_current at 0x7f7c78e...
# 10  <function load_real_estate_valuation at 0x7f7c...
# 11          <function load_wankara at 0x7f7c78e4ce50>
# 12          <function load_plastic at 0x7f7c78e4d1b0>
# 13            <function load_laser at 0x7f7c78e4cc10>
# 14  <function load_qsar_aquatic_toxicity at 0x7f7c...
# 15         <function load_baseball at 0x7f7c78e4cf70>
# 16  <function load_maternal_health_risk at 0x7f7c7...
# 17  <function load_cpu_performance at 0x7f7c78e4d2d0>
# 18          <function load_airfoil at 0x7f7c78e4d240>
# 19     <function load_medical_cost at 0x7f7c78e4dbd0>  , 'estimator': <class 'flipping_random_forest._regressors.OperatorRandomForestRegressor'>, 'function': <function evaluate_regression at 0x7f7ca8350430>, 'label': 'rfr', 'modes': ['<', '<=', 'avg_all', 'avg_half', 'specific']}
# 2023-12-06 21:01:53.309126 diabetes
# 2023-12-06 21:08:31.795798 o-ring
# 2023-12-06 21:15:14.133260 stock_portfolio_performance
# 2023-12-06 21:22:48.867370 wsn-ale
# 2023-12-06 21:30:57.998230 daily-demand
# 2023-12-06 21:40:10.577038 slump_test
# 2023-12-06 21:49:35.605387 servo
# 2023-12-06 21:58:21.613172 yacht_hydrodynamics
# 2023-12-06 22:09:14.965218 autoMPG6
# 2023-12-06 22:21:22.361758 excitation_current
# 2023-12-06 22:33:04.894893 real_estate_valuation
# 2023-12-06 22:43:49.099282 wankara
# 2023-12-06 22:56:07.987682 plastic
# 2023-12-06 23:08:03.018961 laser
# 2023-12-06 23:31:32.730871 qsar-aquatic-toxicity
# 2023-12-06 23:50:18.770358 baseball
# 2023-12-07 00:01:43.038261 maternal_health_risk
# 2023-12-07 00:17:22.927782 cpu_performance
# 2023-12-07 00:30:35.953612 airfoil
# 2023-12-07 00:51:21.821701 medical_cost
