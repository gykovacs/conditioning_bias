# %%
import numpy as np
import pandas as pd

pd.set_option('display.width', 200)

from sklearn.tree import DecisionTreeRegressor

from flipping_random_forest import (MirroredDecisionTreeRegressor, evaluate, grid_point_splits)

from datasets import regr_datasets
# Out:
# 2023-02-20 19:42:01 INFO     querying the filtered classification datasets
# 2023-02-20 19:42:01 INFO     ranking the datasets
# 2023-02-20 19:42:01 INFO     binary classification datasets prepared
# 2023-02-20 19:42:01 INFO     querying the filtered regression datasets
# 2023-02-20 19:42:01 INFO     ranking the datasets
# 2023-02-20 19:42:01 INFO     regression datasets prepared

# %%
results = []
for idx, row in regr_datasets.iterrows():
    dataset = row['data_loader_function']()
    print('processing', dataset['name'])
    X = dataset['data']
    y = dataset['target']
    dtr = DecisionTreeRegressor().fit(X, y)
    result = grid_point_splits(dtr, X, dataset['grid'])
    result['name'] = dataset['name']
    results.append(result)
results = pd.concat(results)
# Out:
# processing o-ring
# processing stock_portfolio_performance
# processing wsn-ale
# processing daily-demand
# processing servo
# processing yacht_hydrodynamics
# processing autoMPG6
# processing excitation_current
# processing real_estate_valuation
# processing wankara
# processing plastic
# processing laser
# processing qsar-aquatic-toxicity
# processing baseball
# processing maternal_health_risk
# processing medical_cost
# processing boom_bikes
# processing wizmir
# processing forestfires
# processing winequality_red

# %%
results.groupby('name').apply(lambda pdf: pd.Series({'name': pdf.iloc[0]['name'],
                                                     'all_nodes': pdf.iloc[0]['all_nodes'],
                                                     'grid': np.sum(pdf['grid_split'])}))
# Out:
#                                                     name  all_nodes  grid
# name
# autoMPG6                                        autoMPG6        322    45
# baseball                                        baseball        318    94
# boom_bikes                                    boom_bikes        720    30
# daily-demand                                daily-demand         59     3
# excitation_current                    excitation_current        346     1
# forestfires                                  forestfires        332    30
# laser                                              laser        799   300
# maternal_health_risk                maternal_health_risk        166    20
# medical_cost                                medical_cost       1154    13
# o-ring                                            o-ring          5     0
# plastic                                          plastic        879     0
# qsar-aquatic-toxicity              qsar-aquatic-toxicity        536    12
# real_estate_valuation              real_estate_valuation        388    12
# servo                                              servo        137     0
# stock_portfolio_performance  stock_portfolio_performance         19     0
# wankara                                          wankara        310     0
# winequality_red                          winequality_red        411    75
# wizmir                                            wizmir       1345     0
# wsn-ale                                          wsn-ale        106     0
# yacht_hydrodynamics                  yacht_hydrodynamics        298     0

# %%
regr_datasets
# Out:
#                            name citation_key  n_col     n  n_grid                                               grid                               data_loader_function
# 0                        o-ring          uci      6    23       3              [True, False, True, True, True, True]           <function load_o_ring at 0x7f52752876d0>
# 1   stock_portfolio_performance          uci      6    63       1          [False, False, False, False, False, True]  <function load_stock_portfolio_performance at ...
# 2                       wsn-ale          uci      5   107       1                 [False, False, True, False, False]          <function load_wsn_ale at 0x7f52752877f0>
# 3                  daily-demand          uci     12    60       2  [True, True, False, False, False, False, False...     <function load_daily_demand at 0x7f5275287760>
# 4                         servo          uci     10   167       2  [True, True, True, True, True, True, True, Tru...            <function load_servo at 0x7f5275287880>
# 5           yacht_hydrodynamics         krnn      6   307       1          [False, False, False, False, False, True]  <function load_yacht_hydrodynamics at 0x7f5275...
# 6                      autoMPG6         keel      5   392       2                  [False, True, False, False, True]         <function load_autoMPG6 at 0x7f5275286d40>
# 7            excitation_current          uci      4   557       2                         [True, True, False, False]  <function load_excitation_current at 0x7f52752...
# 8         real_estate_valuation          uci      6   414       2           [True, False, False, True, False, False]  <function load_real_estate_valuation at 0x7f52...
# 9                       wankara         keel      9   321       2  [False, False, False, False, True, True, False...          <function load_wankara at 0x7f5275286e60>
# 10                      plastic         keel      2  1650       2                                       [True, True]          <function load_plastic at 0x7f52752871c0>
# 11                        laser         keel      4   993       4                           [True, True, True, True]            <function load_laser at 0x7f5275286cb0>
# 12        qsar-aquatic-toxicity          uci      8   546       3  [False, False, True, False, False, False, True...  <function load_qsar_aquatic_toxicity at 0x7f52...
# 13                     baseball         keel     16   337      10  [False, False, True, True, True, True, True, T...         <function load_baseball at 0x7f5275286f80>
# 14         maternal_health_risk          uci      6  1013       1          [True, False, False, False, False, False]  <function load_maternal_health_risk at 0x7f527...
# 15                 medical_cost      mlwithr      6  1338       1              [False, True, True, True, True, True]     <function load_medical_cost at 0x7f5275287be0>
# 16                   boom_bikes    boombikes     13   730       4  [True, True, True, True, True, True, True, Fal...       <function load_boom_bikes at 0x7f5275287b50>
# 17                       wizmir         keel      9  1461       2  [False, False, True, False, True, False, False...           <function load_wizmir at 0x7f5275286dd0>
# 18                  forestfires         krnn     27   517       3  [True, True, False, False, False, False, False...      <function load_forestfires at 0x7f5275287370>
# 19              winequality_red         krnn     11  1599       4  [True, False, False, False, False, True, True,...  <function load_winequality_red at 0x7f5275287490>

# %%
data_loaders = regr_datasets['data_loader_function'].values.tolist()

# %%
scenarios=[{'name': 'original',
            'estimator': DecisionTreeRegressor,
            'estimator_params': {'min_samples_leaf': 2, 'max_features': 'sqrt'},
            'multiplier': 1},
            
            {'name': 'mirrored',
            'estimator': MirroredDecisionTreeRegressor,
            'estimator_params': {'min_samples_leaf': 2, 'max_features': 'sqrt'},
            'multiplier': 1},
            
            {'name': 'inverted',
            'estimator': DecisionTreeRegressor,
            'estimator_params': {'min_samples_leaf': 2, 'max_features': 'sqrt'},
            'multiplier': -1}]
            
compare=[('original', 'mirrored'), 
            ('original', 'inverted')]

total = 10_000

validator_params = {'n_repeats': total/5,
                    'n_splits': 5,
                    'random_state': 5}

validator_params_5 = {'n_repeats': total/5,
                    'n_splits': 5,
                    'random_state': 5}

validator_params_4 = {'n_repeats': total/4,
                    'n_splits': 4,
                    'random_state': 5}

validator_params_3 = {'n_repeats': int(total/3),
                    'n_splits': 3,
                    'random_state': 5}

validator_params_2 = {'n_repeats': total/2,
                    'n_splits': 2,
                    'random_state': 5}

# %%
results_pdf = evaluate(scenarios=scenarios, 
                        compare=compare, 
                        data_loaders=data_loaders,
                        validator_params=validator_params,
                        score='r2',
                        random_state=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 results_pdf = evaluate(scenarios=scenarios,
#       2                         compare=compare,
#       3                         data_loaders=data_loaders,
#       4                         validator_params=validator_params,
#       5                         score='r2',
#       6                         random_state=5)
#
# File ~/workspaces_clean/flipping_random_forest/flipping_random_forest/_core.py:124, in evaluate(scenarios, compare, data_loaders, validator_params, score, random_state)
#     121 y = dataset['target']
#     123 if score == 'r2':
# --> 124     raw_scores = evaluate_scenarios_regression(scenarios, X, y, validator_params, random_state=random_state)
#     125 elif score == 'auc':
#     126     raw_scores = evaluate_scenarios_classification(scenarios, X, y, validator_params, random_state=random_state)
#
# File ~/workspaces_clean/flipping_random_forest/flipping_random_forest/_core.py:147, in evaluate_scenarios_regression(scenarios, X, y, validator_params, random_state)
#     144     random_state = np.random.RandomState(random_state)
#     146 if isinstance(validator_params, dict):
# --> 147     validator = RepeatedKFold(**validator_params)
#     148     for train, test in tqdm.tqdm(validator.split(X, y)):
#     149         random_seed = None
#
# File ~/anaconda3/envs/smote_clean/lib/python3.10/site-packages/sklearn/model_selection/_split.py:1570, in RepeatedKFold.__init__(self, n_splits, n_repeats, random_state)
#    1569 def __init__(self, *, n_splits=5, n_repeats=10, random_state=None):
# -> 1570     super().__init__(
#    1571         KFold, n_repeats=n_repeats, random_state=random_state, n_splits=n_splits
#    1572     )
#
# File ~/anaconda3/envs/smote_clean/lib/python3.10/site-packages/sklearn/model_selection/_split.py:1434, in _RepeatedSplits.__init__(self, cv, n_repeats, random_state, **cvargs)
#    1432 def __init__(self, cv, *, n_repeats=10, random_state=None, **cvargs):
#    1433     if not isinstance(n_repeats, numbers.Integral):
# -> 1434         raise ValueError("Number of repetitions must be of Integral type.")
#    1436     if n_repeats <= 0:
#    1437         raise ValueError("Number of repetitions must be greater than 0.")
#
# ValueError: Number of repetitions must be of Integral type.

# %%
results_pdf[['name', 'r2_mean_original', 'r2_mean_mirrored', 'r2_mean_inverted', 'p_original_mirrored', 'p_original_inverted']]

# %%
results_pdf.to_csv('existance-regression-dt.csv')
