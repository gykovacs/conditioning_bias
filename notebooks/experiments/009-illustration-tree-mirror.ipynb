# %%
import numpy as np

# %%
from flipping_random_forest import (mirror_tree, dummy_data)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
dataset = dummy_data()

# %%
tree = DecisionTreeClassifier(criterion='gini').fit(dataset['data'], dataset['target'])

# %%
plot_tree(tree)
# Out:
# [Text(0.6, 0.8333333333333334, 'x[2] <= 5.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.4, 0.5, 'x[0] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
mtree = mirror_tree(tree)
plot_tree(mtree)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[2] <= -5.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6, 0.5, 'x[0] <= -0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
plot_tree(tree)
# Out:
# [Text(0.6, 0.8333333333333334, 'x[2] <= 5.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.4, 0.5, 'x[0] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
tree.predict_proba(np.array([0, 40, 5]).reshape(1, -1))
# Out:
# array([[0., 1.]])

# %%
mtree.predict_proba(np.array([-0, -40, -5]).reshape(1, -1))
# Out:
# array([[1., 0.]])
