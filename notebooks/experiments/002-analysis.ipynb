# %%
import numpy as np
import pandas as pd

# %%
data_reg = pd.read_csv('regression.csv')
data_clf = pd.read_csv('classification.csv')

# %%
data_reg[['name', 'r2_baseline', 'r2_flipping_full', 'r2_flipping_coord', 'p_full', 'p_coord']]
# Out:
#                            name  r2_baseline  r2_flipping_full  \
# 0                      autoMPG6     0.872023          0.871988
# 1                      baseball     0.668028          0.667533
# 2                    boom_bikes     0.996083          0.996094
# 3                  daily-demand     0.819053          0.822217
# 4            excitation_current     0.999906          0.999911
# 5                         laser     0.963003          0.963370
# 6          maternal_health_risk     0.752530          0.753107
# 7                  medical_cost     0.693810          0.693912
# 8                        o-ring     0.140417          0.157057
# 9                       plastic     0.714930          0.714104
# 10        qsar-aquatic-toxicity     0.523731          0.523877
# 11        real_estate_valuation     0.693253          0.692901
# 12         residential_building     0.958055          0.958030
# 13                        servo     0.631489          0.631111
# ...

# %%
data_clf[['name', 'auc_baseline', 'auc_flipping_full', 'auc_flipping_coord', 'p_full', 'p_coord']]
# Out:
#                             name  auc_baseline  auc_flipping_full  \
# 0                    abalone9_18      0.831543           0.829827
# 1                     australian      0.926573           0.926603
# 2                           bupa      0.764138           0.762466
# 3               cleveland-0_vs_4      0.972175           0.973268
# 4                         ecoli1      0.954147           0.954405
# 5                       haberman      0.667635           0.670004
# 6                      hepatitis      0.876280           0.876141
# 7   lymphography-normal-fibrosis      0.993807           0.995094
# 8                   mammographic      0.867652           0.868304
# 9                   new_thyroid1      0.999199           0.999132
# 10                          pima      0.823378           0.823358
# 11                  poker-9_vs_7      0.985457           0.986821
# 12                       saheart      0.722078           0.721474
# ...

# %%
data_reg[['name', 'r2_baseline', 'r2_flipping_full', 'r2_flipping_coord', 'p_full', 'p_coord']].median()
# Out:
# /tmp/ipykernel_31647/3674400262.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_reg[['name', 'r2_baseline', 'r2_flipping_full', 'r2_flipping_coord', 'p_full', 'p_coord']].median()
# r2_baseline          0.785792
# r2_flipping_full     0.787662
# r2_flipping_coord    0.788691
# p_full               0.201711
# p_coord              0.071209
# dtype: float64

# %%
data_clf[['name', 'auc_baseline', 'auc_flipping_full', 'auc_flipping_coord', 'p_full', 'p_coord']].median()
# Out:
# /tmp/ipykernel_31647/2672977466.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_clf[['name', 'auc_baseline', 'auc_flipping_full', 'auc_flipping_coord', 'p_full', 'p_coord']].median()
# auc_baseline          0.926573
# auc_flipping_full     0.926603
# auc_flipping_coord    0.926654
# p_full                0.465738
# p_coord               0.292047
# dtype: float64
